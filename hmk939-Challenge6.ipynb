# %%
import numpy as np
import time

def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]

        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new

    return x, max_iterations

# %% [markdown]
# Jacobi method function

# %%
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = x.copy()
        
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
            
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        
        x = x_new
        
    return x, max_iterations

# %% [markdown]
# Gauss-sidel function

# %%
A = np.array([[10, -1, 2, 0, 0], [-1, 11, -1, 3, 0], [2, -1, 10, -1, 0], [0, 3, -1, 8, -2], [0, 0, 0, -2, 9]], dtype=float)
b = np.array([14, 30, 26, 25, 37], dtype=float)
A1 = np.array([[1, 2, 3, 0, 0], [2, 1, 2, 3, 0], [3, 2, 1, 2, 3], [0, 3, 2, 1, 2], [0, 0, 3, 2, 1]], dtype=float)
b1 = np.array([14, 22, 33, 26, 22], dtype=float)
x0 = np.zeros_like(b)
x01 = np.zeros_like(b1)
tol = 1e-6
max_iterations = 100
tij = time.perf_counter()
solutionj, iterationsj = jacobi(A, b, x0, tol, max_iterations)
tj = time.perf_counter() - tij
ti = time.perf_counter()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
t = time.perf_counter() - ti
print(f"Solution Jacobi part a: {solutionj}")
print(f"Iterations Jacobi part a: {iterationsj}")
print(f"Time Jacobi part a: {tj}")
print(f"Solution Gauss part a: {solution}")
print(f"Iterations Gauss part a: {iterations}")
print(f"Time Gauss part a: {t}")
tij1 = time.perf_counter()
solutionj1, iterationsj1 = jacobi(A1, b1, x0, tol, max_iterations)
tj1 = time.perf_counter() - tij1
ti1 = time.perf_counter()
solution1, iterations1 = gauss_seidel(A1, b1, x01, tol, max_iterations)
t1 = time.perf_counter() - ti1
print(f"Solution Jacobi part b: {solutionj1}")
print(f"Iterations Jacobi part b: {iterationsj1}")
print(f"Time Jacobi part b: {tj1}")
print(f"Solution Gauss part b: {solution1}")
print(f"Iterations Gauss part b: {iterations1}")
print(f"Time Gauss part b: {t1}")
# Out:
# Solution Jacobi part a: [0.99999995 2.00000025 2.99999986 4.00000008 4.99999983]
# Iterations Jacobi part a: 18
# Time Jacobi part a: 0.0012207170948386192
# Solution Gauss part a: [1.00000003 2.00000002 2.99999999 3.99999998 5.        ]
# Iterations Gauss part a: 10
# Time Gauss part a: 0.0007932558655738831
# Solution Jacobi part b: [-3.43010894e+85 -4.24934579e+85 -5.28966155e+85 -4.24934579e+85
#  -3.43010894e+85]
# Iterations Jacobi part b: 100
# Time Jacobi part b: 0.005540816113352776
# Solution Gauss part b: [-8.70303388e+112  3.37515847e+113 -5.07312279e+113 -1.50300774e+113
#   1.82253839e+114]
# Iterations Gauss part b: 100
# Time Gauss part b: 0.005054206121712923

# %% [markdown]
# Part a: took 18 iterations in .00122 seconds for Jacobi and 10 iterations in 0.000793 seconds for Gauss
# Part b: didn't converge for either
